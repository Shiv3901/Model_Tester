# %%
# DEMO TEST FOR PRESENTATION #

# %%
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (15,9)

from tools_ import Generate as Class   # import the custom python package

# %%
config_info = {
    "paths": ["run_2.csv"],
    "prefix": "Test ",
    "suffix_main_titles": ["50 cars"],
    "labels_of_decisions": ["Decision 1", "Decision 2", "Decision 3", "Decision 4", "Normal AHP", "Advanced AHP"],
    "direc": "datasets",
    "no_of_decisions": 6,
    "blurb": ": Evaluating decision making models with 4 lanes and "
}

runs = Class.Generate(config_info)

# %%
runs.generate_moving_avg_plot(120) # pass the window size as parameter
