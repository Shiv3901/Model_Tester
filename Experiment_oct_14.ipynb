# %%
import pandas as pd
from matplotlib import pyplot as plt
from plotly import graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import pandas as pd
import math
# import numpy as pd

plt.rcParams["figure.figsize"] = (15,5)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from tools_ import Generate as Class
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
paths_1 = ["run_1.csv", "run_2.csv", "run_3.csv", "run_4.csv"]

# %%
runs_no_1 = Generate.Generate("run_no_1",paths_1, 4)

# %%
# _ = runs_no_1.generate_moving_avg_plot("decision", "Evaluating Various Lane Changing Decisions", 50)

# %%
paths_2 = ["run_1.csv", "run_2.csv", "run_3.csv", "run_4.csv"]

# %%
runs_no_2 = Generate.Generate("run_no_2", paths_2, 4)

# %%
# _ = runs_1.generate_moving_avg_plot("decision", "Evaluating Various Lane Changing Decisions", 40)

# %%
paths_4 = ["run_11.csv"]
runs_4 = Generate.Generate("trial", paths_4, 5)

# %%
# _ = runs_4.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 500, 40) # variable, title, width, window size

# %%
paths_5 = ["run_7.csv"]
runs_5 = Generate.Generate("trial_2", paths_5, 2)

# %%
 _ = runs_5.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 500, 30) # variable, title, width, window size

# %%
paths_8 = ["run_10.csv"]
runs_8 = Generate.Generate("trial_2", paths_8, 4)

# %%
 _ = runs_8.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 500, 30) # variable, title, width, window size

# %%
paths_9 = ["run_19.csv"]
runs_9 = Generate.Generate("trial_2", paths_9, 4)

# %%
 _ = runs_9.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 500, 30) # variable, title, width, window size

# %%
paths_final = ["run_4.csv"]
runs_final = Generate.Generate("run_final", paths_final, 5) # keep this one and try to improve on this one lol
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]

# %%
 _ = runs_final.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 100, titles) # variable, title, width, window size

# %%
paths_final_2 = ["run_6.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 140, titles) # variable, title, width, window size

# %%
paths_final_2 = ["run_7.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 120, titles) # variable, title, width, window size

# %%
paths_final_2 = ["run_9.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 130, titles) # variable, title, width, window size

# %%
paths_final_2 = ["run_10.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 190, titles)

# %%
paths_final_2 = ["run_12_weights.csv"]
titles = []
runs_final_2 = Generate.Generate("run_final", paths_final_2, 6)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 120, titles)

# %%
paths_final_2 = ["run_15.csv"]
titles = []
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)
_ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 100, titles)

# %%
paths_final_2 = ["run_16.csv"]
titles = []
runs_final_2 = Generate.Generate("run_final", paths_final_2, 6)
_ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 120, titles)

# %%
paths_final_2 = ["run_17.csv"]
titles = []
runs_final_2 = Generate.Generate("run_final", paths_final_2, 6)
_ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions 50 cars", 120, titles)

# %%
paths_final_2 = ["run_20.csv"] # improved AHP model which takes advantage of A being better in more cars on 4 lanes
titles = []
runs_final_2 = Generate.Generate("run_final", paths_final_2, 6)
_ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions 60 cars", 130, titles)

# %%
# Real testing starts from here

# if titles are not given then:

#     - decision 1: picks the nearest lane 
#     - decision 2: picks the lane that has the minimum number of cars in front of it
#     - decision 3: picks the lane that the car has travelled the most in 
#     - decision 4: picks the lane that has the minimum number of cars in front of it
#     - decision 5: AHP model picks the lane from the above four decisions from above
#     - decision 6: Advanced AHP model that picks the lane from the above four decisions and the normal AHP model

# %%
titles = ["D1", "D2", "D3", "D4", "Normal AHP", "Advanced AHP"]
# titles = []

# %%
# TEST 1: 30 cars and 6 decisions 

paths_1 = ["run_1.csv"] # improved AHP model which takes advantage of A being better in more cars on 4 lanes
runs_1 = Generate.Generate("runs_cars", paths_1, 6)
_ = runs_1.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions 30 cars", 120, titles)

# %%
# TEST 2: 40 cars and 6 decisions (it has only 5 runs each decision)

paths_1 = ["run_2.csv"] # improved AHP model which takes advantage of A being better in more cars on 4 lanes
runs_1 = Generate.Generate("runs_cars", paths_1, 6)
_ = runs_1.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions 40 cars", 120, titles)

# %%
# TEST 3: 50 cars and 6 decisions (it has only 5 runs each decision)

paths_1 = ["run_3.csv"] # improved AHP model which takes advantage of A being better in more cars on 4 lanes
runs_1 = Generate.Generate("runs_cars", paths_1, 6)
_ = runs_1.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions 50 cars", 120, titles)

# %%
# TEST 4: 60 cars and 6 decisions (Run 20 for ref and it has only 5 runs each decision)

paths_1 = ["run_4.csv"] # improved AHP model which takes advantage of A being better in more cars on 4 lanes
runs_1 = Generate.Generate("runs_cars", paths_1, 6)
_ = runs_1.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions 60 cars", 120, titles)

# %%
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
 # TESTING FOR THE FIRST TIME 

# REFACTORED ALL THE CODE THAT I HAD EVER WRITTEN

import pandas as pd
from matplotlib import pyplot as plt
from plotly import graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import pandas as pd
import math
# import numpy as pd

plt.rcParams["figure.figsize"] = (15,5)
from tools_ import Generate as Class

config_info = {
    "paths": ["run_1.csv", "run_2.csv", "run_3.csv", "run_4.csv"],
    "prefix": "Test: ",
    "suffix_main_titles": ["30 cars", "40 cars", "50 cars", "60 cars"],
    "labels_of_decisions": ["Decision 1", "Decision 2", "Decision 3", "Decision 4", "Normal AHP", "Advanced AHP"],
    "direc": "runs_cars",
    "no_of_decisions": 6,
    "blurb": ": Evaluating decision making models with "
}

runs = Class.Generate(config_info)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
runs.generate_moving_avg_plot(120)

# %%
config_info = {
    "paths": ["run_5.csv"],
    "prefix": "Test: ",
    "suffix_main_titles": ["70 cars"],
    "labels_of_decisions": ["Decision 1", "Decision 2", "Decision 3", "Decision 4", "Normal AHP", "Advanced AHP"],
    "direc": "runs_cars",
    "no_of_decisions": 6,
    "blurb": ": Evaluating decision making models with "
}

runs = Class.Generate(config_info)
runs.generate_moving_avg_plot(120)

# %%
config_info = {
    "paths": ["run_6.csv"],
    "prefix": "Test: ",
    "suffix_main_titles": ["80 cars"],
    "labels_of_decisions": ["Decision 1", "Decision 2", "Decision 3", "Decision 4", "Normal AHP", "Advanced AHP"],
    "direc": "runs_cars",
    "no_of_decisions": 6,
    "blurb": ": Evaluating decision making models with "
}

runs = Class.Generate(config_info)
runs.generate_moving_avg_plot(120)
