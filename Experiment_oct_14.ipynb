# %%
import pandas as pd
from matplotlib import pyplot as plt
from plotly import graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import pandas as pd
import math
# import numpy as pd

plt.rcParams["figure.figsize"] = (15,5)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from tools_ import Generate
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
paths_1 = ["run_1.csv", "run_2.csv", "run_3.csv", "run_4.csv"]

# %%
runs_no_1 = Generate.Generate("run_no_1",paths_1, 4)

# %%
# _ = runs_no_1.generate_moving_avg_plot("decision", "Evaluating Various Lane Changing Decisions", 50)

# %%
paths_2 = ["run_1.csv", "run_2.csv", "run_3.csv", "run_4.csv"]

# %%
runs_no_2 = Generate.Generate("run_no_2", paths_2, 4)

# %%
# _ = runs_1.generate_moving_avg_plot("decision", "Evaluating Various Lane Changing Decisions", 40)

# %%
paths_4 = ["run_11.csv"]
runs_4 = Generate.Generate("trial", paths_4, 5)

# %%
# _ = runs_4.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 500, 40) # variable, title, width, window size

# %%
paths_5 = ["run_7.csv"]
runs_5 = Generate.Generate("trial_2", paths_5, 2)

# %%
 _ = runs_5.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 500, 30) # variable, title, width, window size

# %%
paths_8 = ["run_10.csv"]
runs_8 = Generate.Generate("trial_2", paths_8, 4)

# %%
 _ = runs_8.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 500, 30) # variable, title, width, window size

# %%
paths_9 = ["run_19.csv"]
runs_9 = Generate.Generate("trial_2", paths_9, 4)

# %%
 _ = runs_9.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 500, 30) # variable, title, width, window size

# %%
paths_final = ["run_4.csv"]
runs_final = Generate.Generate("run_final", paths_final, 5) # keep this one and try to improve on this one lol
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]

# %%
 _ = runs_final.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 100, titles) # variable, title, width, window size

# %%
paths_final_2 = ["run_6.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 140, titles) # variable, title, width, window size

# %%
paths_final_2 = ["run_7.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 120, titles) # variable, title, width, window size

# %%
paths_final_2 = ["run_9.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 130, titles) # variable, title, width, window size

# %%
paths_final_2 = ["run_10.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_moving_avg_plot("decision", "Evaluating Lane Changing Decisions", 190, titles)

# %%
paths_final_2 = ["run_11_1000_turns.csv"]
titles = ["deci 1", "deci 2", "deci 3", "deci 4", "AHP"]
runs_final_2 = Generate.Generate("run_final", paths_final_2, 5)

# %%
 _ = runs_final_2.generate_all_plots("decision", "Evaluating Lane Changing Decisions", 5000, 200, titles)
